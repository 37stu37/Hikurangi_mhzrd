# %%
import numpy as np
import matplotlib.pyplot as plt
from openquake.hazardlib.nrml import to_python

# %%
fname = '../source_model_Alex.xml'
sm = to_python(fname)

# %%
fig = plt.figure(figsize=(10, 10))
for idx, edge in enumerate(src[0].edges):
    coo = np.array([[p.longitude, p.latitude, p.depth] for p in edge.points])
    plt.plot(coo[:, 0], coo[:,1])
    plt.text(coo[0, 0], coo[0,1], '{:d}'.format(idx))
